# %% [markdown]
# # **Homework** : Basic Statistics
# ## Nama  : Aldiva Wibowo
# ## Class : Data Science B

# %% [markdown]
# ![soal_basicstatistics.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 1. Import Package dan Dataset

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
data.head()
# Out:
#            id             date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0  ... -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0  ... -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0  ... -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0  ... -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2. Statistic Descriptive

# %%
data.describe()
# Out:
#                  id         price  ...  sqft_living15     sqft_lot15
# count  2.161300e+04  2.161300e+04  ...   21613.000000   21613.000000
# mean   4.580302e+09  5.400881e+05  ...    1986.552492   12768.455652
# std    2.876566e+09  3.671272e+05  ...     685.391304   27304.179631
# min    1.000102e+06  7.500000e+04  ...     399.000000     651.000000
# 25%    2.123049e+09  3.219500e+05  ...    1490.000000    5100.000000
# 50%    3.904930e+09  4.500000e+05  ...    1840.000000    7620.000000
# 75%    7.308900e+09  6.450000e+05  ...    2360.000000   10083.000000
# max    9.900000e+09  7.700000e+06  ...    6210.000000  871200.000000
#
# [8 rows x 20 columns]

# %%
data.describe().T
# Out:
#                  count          mean  ...           75%           max
# id             21613.0  4.580302e+09  ...  7.308900e+09  9.900000e+09
# price          21613.0  5.400881e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21613.0  3.370842e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21613.0  2.114757e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21613.0  2.079900e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21613.0  1.510697e+04  ...  1.068800e+04  1.651359e+06
# floors         21613.0  1.494309e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21613.0  7.541757e-03  ...  0.000000e+00  1.000000e+00
# view           21613.0  2.343034e-01  ...  0.000000e+00  4.000000e+00
# condition      21613.0  3.409430e+00  ...  4.000000e+00  5.000000e+00
# grade          21613.0  7.656873e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21613.0  1.788391e+03  ...  2.210000e+03  9.410000e+03
# ...

# %% [markdown]
# ### 3. Statistics Descriptive for Variable

# %%
data['grade'].describe()
# Out:
# count    21613.000000
# mean         7.656873
# std          1.175459
# min          1.000000
# 25%          7.000000
# 50%          7.000000
# 75%          8.000000
# max         13.000000
# Name: grade, dtype: float64

# %%
data['grade'].plot.density()

# %% [markdown]
# Untuk kolom grade, memiliki rentang nilai dari min 1 sampai max 13. karena ini adalah dataset rumah maka tingkat rumah bervariasi dari range 1 yang paling rendah sampai grade 13 yang paling tinggi. lalu karena ini rumah adalah objek pengamatan yang dibandingkan dengan objek yang sama yaitu grade rumah maka tipe data ini adalah jenis kategori ordinal. pada graphic menunjukkan sebaran data mengarah ke kemiringan yang positif. maka dikarenakan sebaran data yang tidak normal atau skew lebih tepatnya positive skewed maka nilai yang digunakan untuk menyimpulkan dapat menggunakan nilai tengah atau median

# %%
data['condition'].describe()
# Out:
# count    21613.000000
# mean         3.409430
# std          0.650743
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: condition, dtype: float64

# %%
data['condition'].plot.density()

# %% [markdown]
# Data condition adalah bagaimana kondisi rumah. untuk tipe data dari kolom ini bisa dikategorikan ke dalam ordinal juga karena membanding antar objek pengamatan yang sama. lalu nilai terendah untuk kondisi rumah ini adalah 1 dan yang tertinggi adalah 5. graphic menunjukkan bahwa sebaran data memiliki derajat kemiringan yang cenderung ke arah kanan atau positif. maka karena nilai mean yang tinggi dan modus yang rendah, lebih baik menggunakan nilai median atau nilai tengah untuk menyimpulkan data

# %%
data['yr_built'].describe()
# Out:
# count    21613.000000
# mean      1971.005136
# std         29.373411
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %%
data['yr_built'].plot.density()

# %% [markdown]
# Data yr_build atau tahun rumah di bangun. untuk tahun di bangun rumah ini memiliki nilai terendah atau min yaitu 1900 dan ada kemungkinan juga rumah sudah di renovasi dengan melihat dari kolom yr_renovated, lalu untuk tahun di bangun yang tertinggi yaitu 2015. dilihat dari graphic sebaran data tahun di bangun ini cenderung negative skewed. rata rata ada di nilai 1971 dan kuartil 1 1951, kuartil 2 1975, dan kuartil 3 1977. sekali lagi karena sebaran data yang miring maka lebih baik menggunakan median untuk menyimpulkan data
